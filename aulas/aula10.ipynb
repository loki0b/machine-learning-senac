# %% [markdown]
# **Importando packages necessários**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Leitura das tabelas .csv**

# %%
tabela_cliente = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_customers_dataset.csv')
tabela_localizacao = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_geolocation_dataset.csv')
tabela_pedido = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_order_items_dataset.csv')
tabela_pagamento = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_order_payments_dataset.csv')
tabela_review = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_order_reviews_dataset.csv')
tabela_entrega_pedido = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_orders_dataset.csv')
tabela_descricao_produto = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_products_dataset.csv')
tabela_vendedor = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/olist_sellers_dataset.csv')
tabela_categoria_traduzido = pd.read_csv('/Users/Aluno/Desktop/mlsenac/machine-learning-senac/arquivos-aula10/product_category_name_translation.csv')

# %% [markdown]
# **Checando head das tabelas**

# %%
tabela_cliente.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
tabela_localizacao.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
tabela_pedido.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
tabela_pagamento.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
tabela_review.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
tabela_entrega_pedido.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
tabela_descricao_produto.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
tabela_vendedor.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
tabela_categoria_traduzido.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# **Merge**

# %%
pd.merge(tabela_cliente, tabela_entrega_pedido, on=['customer_id'], how='inner')
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %% [markdown]
# **Processo de união com as demais tabelas disponibilizadas:**
#
# 1 - (Clientes, Entregas)
#
# 2 - (1, Pedidos)
#
# 3 - (2, Pagamentos)
#
# 4 - (3, Review)
#
# 5 - (4, Vendedor)

# %%
merge_table = pd.merge(tabela_cliente, tabela_entrega_pedido, on=['customer_id'], how='inner')
merge_table = pd.merge(merge_table, tabela_pedido, on=['order_id'], how='inner')
merge_table = pd.merge(merge_table, tabela_pagamento, on=['order_id'], how='inner')
merge_table = pd.merge(merge_table, tabela_review, on=['order_id'], how='inner')
merge_table = pd.merge(merge_table, tabela_vendedor, on=['seller_id'], how='inner')

merge_table
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 2       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 3       4c06b42fbf7b97ab10779cda5549cd1c  07d190f123147d9e89d4b922543d7948
# 4       8276de07ef25225d412b8462d73f8664  332cf4e83e16004ba7dca932ce82475b
# ...                                  ...                               ...
# 117324  eda10d7eb51a675d000956fa1aabc7dd  5c22dbb9d8b5385953f2f1e6d9d115a7
# 117325  f0f671d4034e98cdf20f0c452d6db02b  6532316a8c1a7c7a569482db073530bb
# 117326  b90b857a277b080d8078332b3636ab58  7f5f43a9394964ac51bc5d1e0204ead4
# 117327  1ed0c832c2dd99570a59260e71768bdf  82d46759af0369aad49084bacf85a6c3
# 117328  1ed0c832c2dd99570a59260e71768bdf  82d46759af0369aad49084bacf85a6c3
#
#         customer_zip_code_prefix    customer_city customer_state  \
# ...

# %%
merge_table.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'order_item_id', 'product_id',
#        'seller_id', 'shipping_limit_date', 'price', 'freight_value',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'review_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp', 'seller_zip_code_prefix', 'seller_city',
#        'seller_state'],
#       dtype='object')>

# %% [markdown]
# **Cópia do dataframe**

# %%
merge_table_copy = merge_table.copy()

# %% [markdown]
# **Descartando algumas colunas a principio não necessárias**

# %%
merge_table_copy = merge_table.drop(columns=['customer_unique_id', 'customer_city', 'customer_state', 'order_status',
       'order_purchase_timestamp', 'order_approved_at',
       'order_delivered_carrier_date', 'order_delivered_customer_date',
       'order_estimated_delivery_date', 'shipping_limit_date','review_creation_date',
       'review_answer_timestamp','seller_city',
       'seller_state', 'review_comment_title', 'review_comment_message'])

# %% [markdown]
# **Transformando em arrays numpy**
#
# Para melhor manipulação - desempenho

# %%
vetor_cliente = np.array(merge_table_copy.customer_id)
vetor_cepcliente = np.array(merge_table_copy.customer_zip_code_prefix)
vetor_pedido = np.array(merge_table_copy.order_id)
vetor_id_pedido = np.array(merge_table_copy.order_item_id)
vetor_produto = np.array(merge_table_copy.product_id)
vetor_vendedor = np.array(merge_table_copy.seller_id)
vetor_preco_produto = np.array(merge_table_copy.price)
vetor_frete = np.array(merge_table_copy.freight_value)
vetor_parcela = np.array(merge_table_copy.payment_sequential)
vetor_tipopagamento = np.array(merge_table_copy.payment_type)
vetor_pay = np.array(merge_table_copy.payment_installments)
vetor_valorfinal = np.array(merge_table_copy.payment_value)
vetor_review = np.array(merge_table_copy.review_id)
vetor_score = np.array(merge_table_copy.review_score)
vetor_cepvendedor = np.array(merge_table_copy.seller_zip_code_prefix)

# %% [markdown]
# **Novo DataFrame vazio**

# %%
data_frame = pd.DataFrame()

data_frame
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Definindo as colunas do novo dataframe e atribuindo para cada coluna, seu respectivo vetor de dados registrado anteriormente**

# %%
COLUNAS = ['Cliente',
'CEP_Cliente',
'Pedido',
'id_Pedido',
'Produto',
'Vendedor',
'Preco_produto',
'Frete',
'Parcela',
'Tipo_pagamento',
'Installments',
'Valor_total',
'ID_Review',
'CEP_Vendedor',
'Score'
]

# %%
data_frame = pd.DataFrame(columns = COLUNAS)

data_frame.Cliente = vetor_cliente
data_frame.CEP_Cliente = vetor_cepcliente
data_frame.Pedido = vetor_pedido
data_frame.id_Pedido = vetor_id_pedido
data_frame.Produto = vetor_produto
data_frame.Vendedor = vetor_vendedor
data_frame.Preco_produto = vetor_preco_produto
data_frame.Frete = vetor_frete
data_frame.Parcela = vetor_parcela
data_frame.Tipo_pagamento = vetor_tipopagamento
data_frame.Installments = vetor_pay
data_frame.Valor_total = vetor_valorfinal
data_frame.ID_Review = vetor_review
data_frame.CEP_Vendedor = vetor_cepvendedor
data_frame.Score = vetor_score

data_frame
# Out:
#                                  Cliente  CEP_Cliente  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7        14409
# 1       4e7b3e00288586ebd08712fdd0374a03         1151
# 2       b2b6027bc5c5109e529d4dc6358b12c3         8775
# 3       4c06b42fbf7b97ab10779cda5549cd1c        65075
# 4       8276de07ef25225d412b8462d73f8664        90010
# ...                                  ...          ...
# 117324  eda10d7eb51a675d000956fa1aabc7dd        39920
# 117325  f0f671d4034e98cdf20f0c452d6db02b         7231
# 117326  b90b857a277b080d8078332b3636ab58        76400
# 117327  1ed0c832c2dd99570a59260e71768bdf        37610
# 117328  1ed0c832c2dd99570a59260e71768bdf        37610
#
#                                   Pedido  id_Pedido  \
# 0       00e7ee1b050b8499577073aeb2a297a1          1
# 1       b2059ed67ce144a36e2aa97d2c9e9ad2          1
# 2       951670f92359f4fe4a63112aa7306eba          1
# 3       997fd4b37386d10b57d4ac8cdec011a6          1
# ...

# %% [markdown]
# **Informações do dataframe**

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117329 entries, 0 to 117328
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Cliente         117329 non-null  object
#  1   CEP_Cliente     117329 non-null  int64
#  2   Pedido          117329 non-null  object
#  3   id_Pedido       117329 non-null  int64
#  4   Produto         117329 non-null  object
#  5   Vendedor        117329 non-null  object
#  6   Preco_produto   117329 non-null  float64
#  7   Frete           117329 non-null  float64
#  8   Parcela         117329 non-null  int64
#  9   Tipo_pagamento  117329 non-null  object
#  10  Installments    117329 non-null  int64
#  11  Valor_total     117329 non-null  float64
#  12  ID_Review       117329 non-null  object
#  13  CEP_Vendedor    117329 non-null  int64
#  14  Score           117329 non-null  int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 13.4+ MB

# %% [markdown]
# **Agrupando os elementos do dataframe por consumidor**

# %%
data_frame.groupby(by='Cliente').size()
# Out:
# Cliente
# 00012a2ce6f8dcda20d059ce98491703    1
# 000161a058600d5901f007fab4c27140    1
# 0001fd6190edaaf884bcaf3d49edf079    1
# 0002414f95344307404f0ace7a26f1d5    1
# 000379cdec625522490c315e70c7a9fb    1
#                                    ..
# fffcb937e9dd47a13f05ecb8290f4d3e    1
# fffecc9f79fd8c764f843e9951b11341    3
# fffeda5b6d849fbd39689bb92087f431    1
# ffff42319e9b2d713724ae527742af25    1
# ffffa3172527f765de70084a7e53aae8    2
# Length: 97916, dtype: int64

# %% [markdown]
# **Importando os métodos de árvore de decisão**

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# **Para simplificar os dados, removemos todos os elementos não numéricos para que o modelo seja capaz de realizar a execução**

# %%
data_frame['Cliente'] = data_frame['Cliente'].str.replace(r'\D', '')
data_frame['Pedido'] = data_frame['Pedido'].str.replace(r'\D', '')
data_frame['Produto'] = data_frame['Produto'].str.replace(r'\D', '')
data_frame['Vendedor'] = data_frame['Vendedor'].str.replace(r'\D', '')
data_frame['ID_Review'] = data_frame['ID_Review'].str.replace(r'\D', '')

data_frame
# Out:
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_6116\205648117.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame['Cliente'] = data_frame['Cliente'].str.replace(r'\D', '')
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_6116\205648117.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame['Pedido'] = data_frame['Pedido'].str.replace(r'\D', '')
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_6116\205648117.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame['Produto'] = data_frame['Produto'].str.replace(r'\D', '')
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_6116\205648117.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_frame['Vendedor'] = data_frame['Vendedor'].str.replace(r'\D', '')
# ...

# %%
result_data_frame = pd.get_dummies(data_frame, columns=['Tipo_pagamento'])
result_data_frame
# Out:
#                          Cliente  CEP_Cliente                      Pedido  \
# 0             068999211881720087        14409      0071050849957707322971
# 1         4730028858608712037403         1151          205967144362972992
# 2          260275510952946358123         8775      9516709235944631127306
# 3             406427971077955491        65075         9974373861057480116
# 4       827607252254128462738664        90010          631862016861141129
# ...                          ...          ...                         ...
# 117324          1075167500095617        39920  49462463110524497277085909
# 117325       0671403498200452602         7231         7331435643056154391
# 117326  908572770808078332363658        76400        76905458869336527267
# 117327     108322995705926071768        37610      5162460589765251860206
# 117328     108322995705926071768        37610      5162460589765251860206
#
#         id_Pedido                   Produto                   Vendedor  \
# ...

# %% [markdown]
# **Criando um backup**

# %%
reserva = result_data_frame.copy()

reserva
# Out:
#                          Cliente  CEP_Cliente                      Pedido  \
# 0             068999211881720087        14409      0071050849957707322971
# 1         4730028858608712037403         1151          205967144362972992
# 2          260275510952946358123         8775      9516709235944631127306
# 3             406427971077955491        65075         9974373861057480116
# 4       827607252254128462738664        90010          631862016861141129
# ...                          ...          ...                         ...
# 117324          1075167500095617        39920  49462463110524497277085909
# 117325       0671403498200452602         7231         7331435643056154391
# 117326  908572770808078332363658        76400        76905458869336527267
# 117327     108322995705926071768        37610      5162460589765251860206
# 117328     108322995705926071768        37610      5162460589765251860206
#
#         id_Pedido                   Produto                   Vendedor  \
# ...

# %% [markdown]
# **Eliminando clientes com mais de 3 estrelas de satisfação**

# %%
reserva = reserva.drop(reserva[reserva.Score > 3].index)

reserva
# Out:
#                          Cliente  CEP_Cliente                   Pedido  \
# 3             406427971077955491        65075      9974373861057480116
# 7         0372810041857927016263        21010    369525670169482825831
# 18             45800571938861445        13485      3793048208056190003
# 19          19530467435951219042        20920  54813422788333035171945
# 21             52814168460899591        36091       532771277634465595
# ...                          ...          ...                      ...
# 117320  049671902463228846651580         4929     93358729701080188455
# 117323     211018165721598633401        18650          357035504504584
# 117325       0671403498200452602         7231      7331435643056154391
# 117327     108322995705926071768        37610   5162460589765251860206
# 117328     108322995705926071768        37610   5162460589765251860206
#
#         id_Pedido                   Produto                 Vendedor  \
# ...

# %% [markdown]
# **Processo de separação de treino/teste**
#
# Proporções
#
# 70% treino
#
# 30% teste

# %%
y = result_data_frame['Score']

X = result_data_frame.drop('Score', axis=1)

X_train, X_teste, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# **Número de amostras para cada processo**

# %%
X_train.shape, X_teste.shape
# Out:
# ((82130, 17), (35199, 17))

# %% [markdown]
# **Número de targets para cada processo**

# %%
y_train.shape, y_test.shape
# Out:
# ((82130,), (35199,))

# %% [markdown]
# **Criação do classificador**

# %%
cls = DecisionTreeClassifier()

# %% [markdown]
# **Treinamento**

# %%
cls = cls.fit(X_train, y_train)

# %% [markdown]
# **Vetor com as importancias de cada atributo para a determinação do review_score**

# %%
result_data_frame.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Cliente', 'CEP_Cliente', 'Pedido', 'id_Pedido', 'Produto', 'Vendedor',
#        'Preco_produto', 'Frete', 'Parcela', 'Installments', 'Valor_total',
#        'ID_Review', 'CEP_Vendedor', 'Score', 'Tipo_pagamento_boleto',
#        'Tipo_pagamento_credit_card', 'Tipo_pagamento_debit_card',
#        'Tipo_pagamento_voucher'],
#       dtype='object')>

# %%
cls.feature_importances_
# Out:
# array([0.10804942, 0.10806467, 0.10798805, 0.00651511, 0.09473361,
#        0.07492379, 0.07701227, 0.09002379, 0.00275837, 0.03676549,
#        0.08487975, 0.1106814 , 0.07517529, 0.00949722, 0.00774751,
#        0.00230148, 0.00288277])

# %%
from sklearn.tree import plot_tree, export_text

# %%
plt.rcParams['figure.figsize'] = (40, 20)

# %%
'''plt.figure()
plot_tree(cls, filled=False)
plt.show()'''
# Out:
# 'plt.figure()\nplot_tree(cls, filled=False)\nplt.show()'

# %%
data_frame.head()
# Out:
#                     Cliente  CEP_Cliente                  Pedido  id_Pedido  \
# 0        068999211881720087        14409  0071050849957707322971          1
# 1    4730028858608712037403         1151      205967144362972992          1
# 2     260275510952946358123         8775  9516709235944631127306          1
# 3        406427971077955491        65075     9974373861057480116          1
# 4  827607252254128462738664        90010      631862016861141129          1
#
#                   Produto              Vendedor  Preco_produto   Frete  \
# 0  9516079379936978101698  76714480069693656010         124.99   21.88
# 1  0766896614945862518487  76714480069693656010         139.94   17.79
# 2   564744977148034751092  76714480069693656010         149.94   23.36
# 3        8094076568610375  76714480069693656010         199.98  115.77
# 4     8609375091115750004  76714480069693656010         129.60   16.61
#
#    Parcela Tipo_pagamento  Installments  Valor_total                ID_Review  \
# ...

# %%
for feature, importancia in zip(result_data_frame.columns, cls.feature_importances_):
    print(f'{feature}:{importancia*100:.1f}%')
# Out:
# Cliente:10.8%
# CEP_Cliente:10.8%
# Pedido:10.8%
# id_Pedido:0.7%
# Produto:9.5%
# Vendedor:7.5%
# Preco_produto:7.7%
# Frete:9.0%
# Parcela:0.3%
# Installments:3.7%
# Valor_total:8.5%
# ID_Review:11.1%
# CEP_Vendedor:7.5%
# Score:0.9%
# Tipo_pagamento_boleto:0.8%
# Tipo_pagamento_credit_card:0.2%
# Tipo_pagamento_debit_card:0.3%

# %% [markdown]
# **Vetor com predições para checagem do aprendizado**

# %%
result = cls.predict(X_teste)
result
# Out:
# array([4, 5, 3, ..., 5, 5, 5], dtype=int64)

# %% [markdown]
# **Representação das métricas de precisão e médias do modelo**

# %%
print(metrics.classification_report(y_test, result))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.26      0.27      0.26      4522
#            2       0.13      0.14      0.13      1217
#            3       0.16      0.17      0.16      2977
#            4       0.24      0.26      0.25      6634
#            5       0.61      0.59      0.60     19849
#
#     accuracy                           0.43     35199
#    macro avg       0.28      0.28      0.28     35199
# weighted avg       0.44      0.43      0.44     35199

# %% [markdown]
# **Precisão total**

# %%
from sklearn.model_selection import cross_val_score

allScores = cross_val_score(cls, X_train, y_train, cv=10)
allScores.mean()
# Out:
# 0.4294046024595154

# %% [markdown]
# **Split do dataframe em treino e teste**

# %%
X_train, X_test, y_train, y_test = train_test_split(reserva.drop('Score', axis=1), reserva['Score'], test_size=0.2)

# %% [markdown]
# **Quantidade de amostras do treino**

# %%
X_train.shape, X_test.shape
# Out:
# ((23023, 17), (5756, 17))

# %% [markdown]
# **Classificador**

# %%
clf = DecisionTreeClassifier()

# %% [markdown]
# **Treino**

# %%
clf = clf.fit(X_train, y_train)

# %% [markdown]
# **Importancia dos atributos**

# %%
clf.feature_importances_
# Out:
# array([0.10917864, 0.10727172, 0.09361758, 0.0084952 , 0.09489858,
#        0.08459799, 0.08248932, 0.08876593, 0.00174355, 0.03505412,
#        0.09695584, 0.10630449, 0.0727466 , 0.00737717, 0.00618989,
#        0.00162312, 0.00269025])

# %%
result_data_frame.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Cliente', 'CEP_Cliente', 'Pedido', 'id_Pedido', 'Produto', 'Vendedor',
#        'Preco_produto', 'Frete', 'Parcela', 'Installments', 'Valor_total',
#        'ID_Review', 'CEP_Vendedor', 'Score', 'Tipo_pagamento_boleto',
#        'Tipo_pagamento_credit_card', 'Tipo_pagamento_debit_card',
#        'Tipo_pagamento_voucher'],
#       dtype='object')>

# %%
for feature, importancia in zip(reserva.columns, clf.feature_importances_):
    print(f'{feature}:{importancia*100:.1f}%')
# Out:
# Cliente:10.9%
# CEP_Cliente:10.7%
# Pedido:9.4%
# id_Pedido:0.8%
# Produto:9.5%
# Vendedor:8.5%
# Preco_produto:8.2%
# Frete:8.9%
# Parcela:0.2%
# Installments:3.5%
# Valor_total:9.7%
# ID_Review:10.6%
# CEP_Vendedor:7.3%
# Score:0.7%
# Tipo_pagamento_boleto:0.6%
# Tipo_pagamento_credit_card:0.2%
# Tipo_pagamento_debit_card:0.3%
